# %% [markdown]
# # Web Scraping and Brochure Generation

# %% [markdown]
# ## Overview
# This Jupyter notebook demonstrates an automated process for generating company brochures using web scraping and AI-powered content generation. The script leverages several key technologies and libraries to:
#
# 1. Web Scraping: Retrieve and parse website content using requests and BeautifulSoup
# 2. Link Extraction: Automatically identify and filter relevant website links
# 3. AI-Powered Content Generation: Use OpenAI's GPT models to create engaging, professional brochures
#
# ## Key Features
#
# - Scrape website content dynamically
# - Extract and filter website links
# - Generate markdown-formatted brochures
# - Stream brochure content in real-time
# - Customize brochure generation with system prompts
#
# ## Technical Components
#
# ### Libraries:
#
# - Web Scraping: requests, BeautifulSoup
# - Environment Management: python-dotenv
# - AI Interaction: openai
#
#
# - AI Model: GPT-4o-mini
# - Output Format: Markdown
#
# ## Usage
# To generate a brochure for a company:
#
# - Provide the company's website URL
# - Run the stream_brochure() function
# - Watch as the AI generates a dynamic, engaging brochure
#
# ## Prerequisites
#
# - Activated Python environment
# - OpenAI API key
# - Required Python libraries installed

# %%
# imports
import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage
# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
vlf = Website("https://villefranche-sur-mer.fr")
print(vlf.get_contents())
vlf.links
# Out:
# Webpage Title:
# Villefranche-sur-Mer – Site de la commune de Villefranche-sur-Mer
# Webpage Contents:
# Villefranche-sur-Mer
# Site de la commune de Villefranche-sur-Mer
# Accueil
# Mairie
# Conseil municipal
# Ordre du jour du conseil municipal
# Procès Verbaux
# Documents budgétaires
# Arrêtés municipaux
# Actes règlementaires
# Compte-Rendu et liste des délibérations de Conseils Municipaux 2020 – 2025
# Les fonctions du maire
# Les élus municipaux
# Services municipaux
# Organigramme des services
# Services administratifs
# Services techniques
# Le service des mouillages
# Marchés Publics & Concessions
# Enquêtes Publiques
# Démarches administratives
# Changement d’usage
# Abattage d’arbre ou défrichement
# Ouverture de l’Espace France Services
# Etat-civil
# Démarches en ligne
# Communication / presse
# Magazines Municipaux
# Villefranche News
# La Ville s’engage en faveur de l’environnement !
# Villefranche-sur-Mer et sa charte de l’arbre
# Logo & charte graphique
# Presse : communiqués & agendas
# Présentation service Urbanisme
# Service urbanisme
# PLUm – Version définitive approuvé le 25 Octobre 2019
# PLUm – Modification simplifiée n°1 du 21 octobre 2021
# PLum – Révision générale n°1 – Début de la concertation publique le 4 juillet 2022
# PLUm – Modification simplifiée n°2 du 30 novembre 2023
# Vie locale
# Famille
# Petite enfance
# Les seniors
# Social & santé
# Centre Communal d’Action Sociale
# L’aide sociale
# EHPAD Public
# Education
# Etablissements scolaires
# Inscriptions 2024 / 2025
# Listes des Fournitures Scolaires
# Scolabus
# Restauration scolaire
# Portail famille de Villefranche-sur-Mer
# Vie associative
# Annuaire des Associations
# Demandes de subventions
# Sécurité
# Police municipale
# Voisins vigilants
# Vidéoprotection
# Réserve Communale de Sécurité Civile : appel aux volontaires
# Economie
# Les Marchés à Villefranche
# Occupation du domaine public
# Vie quotidienne
# Consultation locale sur l’aménagement d’un sens unique de circulation en centre-ville – Convocation des électeurs au scrutin du samedi 4 décembre 2021
# Parkings – Stationnement & tarifs
# Stationnement en zone bleue
# Service voiturier 2024
# Transports
# Environnement
# Villefranche et la mer
# Propreté / Voirie
# Label Villes et Villages Fleuris
# Culture
# Faire un don pour le Bastion de la Turbie
# Musées
# Volti
# Goetz – Boumeester
# Collection Roux
# 24 ème BCA
# Horaires d’ouverture
# Boutique des musées
# Animations culturelles
# Animations au coeur des musées
# Atelier Municipal de sculptures
# Expositions temporaires
# Chapelle Saint-Elme
# Chapelle Sainte-Elisabeth
# Villefranche Patrimoine
# Villefranche et le Cinéma
# Cocteau et Villefranche
# Villefranche et les Russes
# Villefranche et les Américains
# Centenaire 1914-1918
# Sport, Loisirs & Associations
# Associations sportives
# Associations Culturelles
# Associations de Parents d’élèves
# Associations Patriotiques
# Associations Caritatives
# Associations Patrimoine et Environnement
# Associations diverses
# Equipements
# Complexe multisports de la Barmassa
# Gymnase des glacis
# Stade de football Antoine Bonifaci
# Les terrains de tennis
# Gymnase de la Corne d’Or
# Associations de plaisanciers
# CCAS
# Tourisme
# Agenda
# Nous contacter
# Menu
# Accueil
# Mairie
# Conseil municipal
# Ordre du jour du conseil municipal
# Procès Verbaux
# Documents budgétaires
# Arrêtés municipaux
# Actes règlementaires
# Compte-Rendu et liste des délibérations de Conseils Municipaux 2020 – 2025
# Les fonctions du maire
# Les élus municipaux
# Services municipaux
# Organigramme des services
# Services administratifs
# Services techniques
# Le service des mouillages
# Marchés Publics & Concessions
# Enquêtes Publiques
# Démarches administratives
# Changement d’usage
# Abattage d’arbre ou défrichement
# Ouverture de l’Espace France Services
# Etat-civil
# Démarches en ligne
# Communication / presse
# Magazines Municipaux
# Villefranche News
# La Ville s’engage en faveur de l’environnement !
# Villefranche-sur-Mer et sa charte de l’arbre
# Logo & charte graphique
# Presse : communiqués & agendas
# Présentation service Urbanisme
# Service urbanisme
# PLUm – Version définitive approuvé le 25 Octobre 2019
# PLUm – Modification simplifiée n°1 du 21 octobre 2021
# PLum – Révision générale n°1 – Début de la concertation publique le 4 juillet 2022
# PLUm – Modification simplifiée n°2 du 30 novembre 2023
# Vie locale
# Famille
# Petite enfance
# Les seniors
# Social & santé
# Centre Communal d’Action Sociale
# L’aide sociale
# EHPAD Public
# Education
# Etablissements scolaires
# Inscriptions 2024 / 2025
# Listes des Fournitures Scolaires
# Scolabus
# Restauration scolaire
# Portail famille de Villefranche-sur-Mer
# Vie associative
# Annuaire des Associations
# Demandes de subventions
# Sécurité
# Police municipale
# Voisins vigilants
# Vidéoprotection
# Réserve Communale de Sécurité Civile : appel aux volontaires
# Economie
# Les Marchés à Villefranche
# Occupation du domaine public
# Vie quotidienne
# Consultation locale sur l’aménagement d’un sens unique de circulation en centre-ville – Convocation des électeurs au scrutin du samedi 4 décembre 2021
# Parkings – Stationnement & tarifs
# Stationnement en zone bleue
# Service voiturier 2024
# Transports
# Environnement
# Villefranche et la mer
# Propreté / Voirie
# Label Villes et Villages Fleuris
# Culture
# Faire un don pour le Bastion de la Turbie
# Musées
# Volti
# Goetz – Boumeester
# Collection Roux
# 24 ème BCA
# Horaires d’ouverture
# Boutique des musées
# Animations culturelles
# Animations au coeur des musées
# Atelier Municipal de sculptures
# Expositions temporaires
# Chapelle Saint-Elme
# Chapelle Sainte-Elisabeth
# Villefranche Patrimoine
# Villefranche et le Cinéma
# Cocteau et Villefranche
# Villefranche et les Russes
# Villefranche et les Américains
# Centenaire 1914-1918
# Sport, Loisirs & Associations
# Associations sportives
# Associations Culturelles
# Associations de Parents d’élèves
# Associations Patriotiques
# Associations Caritatives
# Associations Patrimoine et Environnement
# Associations diverses
# Equipements
# Complexe multisports de la Barmassa
# Gymnase des glacis
# Stade de football Antoine Bonifaci
# Les terrains de tennis
# Gymnase de la Corne d’Or
# Associations de plaisanciers
# CCAS
# Tourisme
# Agenda
# Nous contacter
# Recent Posts
# Grid
# List
# Retrouvez le Conseil Municipal du 20 janvier 2025
# https://www.youtube.com/watch?v=O6QSrRmhdMQ&t=11s ...
# janvier 21, 2025
# (0) Comments
# Floralies : Recherche d’exposants
# Le Comité des Fêtes recherche des exposants pour les Floralies, le nouveau salon dédié aux fleurs et aux plantes à Villefranche, les 26 et 27 avril 2025, ...
# janvier 17, 2025
# (0) Comments
# Assistez à la projection-débat « Océan Indien : la mission océanographique » organisée par l’Institut de la Mer de Villefranche
# Le jeudi 30 janvier, à 19h Auditorium de La Citadelle Tout public, entrée libre sur inscription : https://www.eventbrite.com/e/mission-ocean-indien-ticket ...
# janvier 16, 2025
# (0) Comments
# Combat Naval Fleuri à Villefranche-sur-Mer, le 17 février
# Lundi 17 février 2024, Villefranche-sur-Mer et les pointus de Méditerranée vous donnent rendez-vous pour leur traditionnelle bataille de fleurs sur l’eau. ...
# janvier 15, 2025
# (0) Comments
# 2ème phase des travaux du Parking Wilson du lundi 13 au lundi 20 janvier
# La 2ème phase des travaux du Parking Wilson aura lieu du lundi 13 au lundi 20 janvier. Les nouveaux candélabres vont être installés. Le parking reste ouve ...
# janvier 09, 2025
# (0) Comments
# Le parking des Marinières est fermé pour travaux jusqu’au 15 mars
# Des tranchées vont être creusées pour permettre l’alimentation en électricité des toilettes publiques et la création d’un réseaux d’arrosage pour les futu ...
# janvier 08, 2025
# (0) Comments
# Collecte des sapins
# Vous souhaitez vous débarrasser de votre sapin de Noël ? Sachez que déposer son arbre sur le trottoir après les fêtes peut entraîner une amende de 135 eur ...
# janvier 06, 2025
# (0) Comments
# « Inondations et coulées de boue » : notre commune non reconnue en état de catastrophe naturelle
# L’arrêté interministériel NOR : INTE2433751A du 16 décembre 2024 a rejeté de l’état de catastrophe naturelle au titre du phénomène « inondations et coulée ...
# janvier 06, 2025
# (0) Comments
# Les collectes de déchets pour la fin de l’année
# Semaine de Noël Semaine du Nouvel An ...
# décembre 24, 2024
# (0) Comments
# Samedi 21 décembre, soirée NOSTALGIE « Génération 80 » : l’after du Trail Urbain Nocturne
# Dans le cadre du Trail urbain nocturne, organisé par la ville de Villefranche et l'association Mounta Cala, qui célèbre les 20 ans de la mythique course é ...
# décembre 11, 2024
# (0) Comments
# Villefranche s’engage pour le Téléthon !
# Mobilisons-nous pour soutenir la recherche contre les maladies génétiques rares et orphelines. Comment participer? Une cagnotte est d'ores et déjà ouverte ...
# novembre 19, 2024
# (0) Comments
# Découvrez la programmation de Noël à Villefranche-sur-Mer, à partir du 7 décembre !
# - Samedi 7 décembre, 17h30 : Illuminations et parade de Noël, de l'Octroi à la Citadelle - Samedi 14 décembre : 15h : Inauguration de la Crèche au Foyer d ...
# novembre 15, 2024
# (0) Comments
# Des barrières de sécurité posées Avenue Albert 1er
# Des barrières de protection ont été posées ce mardi 5 novembre sur les trottoirs de l'Avenue Albert 1er. Des travaux pour sécuriser la circulation des pié ...
# novembre 05, 2024
# (0) Comments
# La Ville recherche un(e) contrôleur(se) de travaux et des infractions en urbanisme H/F
# Cadre d'emploi de Catégorie C Filière technique ou administrative Recrutement par voie statutaire ou contrat à durée déterminée MISSIONS : Placé(e) sous l ...
# novembre 04, 2024
# (0) Comments
# Expositions : Du 16 novembre 2024 au 26 janvier 2025 : Villefranche s’inscrit dans la saison de la Lituanie en France !
# Exposition personnelle d’Emilija Škarnulytė La Citadelle – Centre d’art & Musées invite Emilija Škarnulytė, artiste visuelle et vidéaste, née en 1987 ...
# octobre 24, 2024
# (0) Comments
# Le parking Wilson plus économe en énergie : renouvellement de l’éclairage.
# À partir de lundi 28 octobre et jusqu'au 12 décembre 2024, la mairie va moderniser l’éclairage du parking Wilson. Il sera donc fermé aux voitures et aux d ...
# octobre 23, 2024
# (0) Comments
# Horaires d’ouverture de l’état civil du 23 au 31 octobre 2024
# Du mercredi 23 octobre au jeudi 31 octobre inclus, le service population - état civil et élections - sera ouvert de 8h à 12h et de 13h30 à 16h30. Le vendr ...
# octobre 23, 2024
# (0) Comments
# Inondations octobre 2024 : déclaration de sinistre
# Les 17 et 18 octobre 2024, le département des Alpes-Maritimes a subi des intempéries ayant provoqué des inondations significatives par ruissellement ou cr ...
# octobre 21, 2024
# (0) Comments
# Alerte Rouge « Pluie et Inondation » ce jeudi 17 octobre
# Météo France a émis une vigilance ROUGE « pluie-inondations » pour les Alpes-Maritimes ce jour à 18h00. Les informations en direct : - La Ville a déclench ...
# octobre 17, 2024
# (0) Comments
# La virée des gourmets le dimanche 27 octobre !
# La virée des gourmets fait escale à Villefranche-sur-Mer le dimanche 27 octobre ! Selon l’envie du moment, le grand public pourra participer à une dé ...
# octobre 14, 2024
# (0) Comments
# Fermeture des établissements scolaires ce mardi 08 octobre
# Le département des Alpes-Maritimes est placé en vigilance orange Pluie Inondations à compter de cette nuit, dès 3h du matin. Le Préfet des Alpes-Maritimes ...
# octobre 07, 2024
# (0) Comments
# Démolition & reconstruction de l’EHPAD l’Escalinada – Interdiction de stationnement sur une partie de l’Avenue de la Barmassa
# Le projet de démolition-reconstruction de l’EHPAD l’Escalinada a débuté. La nouvelle construction de plus de 6 000 m², comprendra 102 chambres individuell ...
# octobre 04, 2024
# (0) Comments
# Les travaux de la gare de Villefranche-sur-Mer ont commencé : embellissements et aménagements PMR* prévus !
# La gare de Villefranche-sur-Mer fait partie des 42 gares de la Région PACA qui ont l’obligation légale d’une mise en accessibilité PMR avant le 31 décembr ...
# octobre 03, 2024
# (0) Comments
# Sacré-Cœur : les travaux sont terminés !
# Travaux terminés pour cet espace emblématique de Villefranche-sur-Mer ! La façade du Sacré-Cœur a été entièrement rénovée à l'identique suivant les prescr ...
# septembre 30, 2024
# (0) Comments
# * Attention ! L’utilisation d’un bloqueur de publicité peut empêcher la visualisation des deux onglets ci-dessus !
# Infos utiles :
# Mairie de Villefranche-sur-Mer
# La Citadelle BP7
# 06236 Villefranche-sur-Mer Cedex
# Tél. 04.93.76.33.33
# Ou laissez nous un message.
# Horaires d’ouverture :
# Du Lundi au Vendredi :
# de 08h00 à 12h00
# et de 13h00 à 16h30
# Télépaiements DGFIP
# La Grande émission - Azur Tv -
# Photohèque
# Vidéothèque
# Liens utiles :
# Médiathèque du SIVOM de Villefranche-sur-Mer
# Métropole Nice Côte d'Azur
# Publication du Recueil des Actes Administratifs NCA
# Conseil Départemental
# SIVOM de Villefranche-sur-Mer
# Règlement général sur la Protection des données
# Nous contacter
# Plan du site
# Copyright © 2014 par le service communication de la Mairie de Villefranche-sur-Mer
# ['https://villefranche-sur-mer.fr',
#  'https://villefranche-sur-mer.fr/',
#  'https://villefranche-sur-mer.fr/mairie/',
#  'https://villefranche-sur-mer.fr/conseil-municipal/',
#  'https://villefranche-sur-mer.fr/deliberations-du-conseil-municipal/',
#  'https://villefranche-sur-mer.fr/comptes-rendus-des-conseils-municipaux/',
#  'https://villefranche-sur-mer.fr/documents-budgetaires/',
#  'https://villefranche-sur-mer.fr/actes-reglementaires/',
#  'https://villefranche-sur-mer.fr/actes-reglementaires-2/',
#  'https://villefranche-sur-mer.fr/deliberations-2/',
#  'https://villefranche-sur-mer.fr/le-maire/',
#  'https://villefranche-sur-mer.fr/les-elus-municipaux/',
#  'https://villefranche-sur-mer.fr/services-municipaux/',
#  'https://villefranche-sur-mer.fr/organigramme-des-services/',
#  'https://villefranche-sur-mer.fr/services-administratifs/',
#  'https://villefranche-sur-mer.fr/services-techniques/',
#  'https://villefranche-sur-mer.fr/le-service-des-mouillages/',
#  'https://villefranche-sur-mer.fr/marches-publics/',
#  'https://villefranche-sur-mer.fr/enquetes-publiques/',
#  'https://villefranche-sur-mer.fr/demarches-administratives/',
#  'https://villefranche-sur-mer.fr/vous-etes-proprietaire-dun-logement-et-vous-desirez-le-proposer-en-location-meublee-touristique-vous-etes-proprietaire-ou-locataire-et-vous-desirez-transformer-un-logement-pour-y-exercer-vo/',
#  'https://villefranche-sur-mer.fr/abattage-arbre-ou-defrichement/',
#  'https://villefranche-sur-mer.fr/ouverture-de-lespace-france-services/',
#  'https://villefranche-sur-mer.fr/etat-civil/',
#  'https://villefranche-sur-mer.fr/demarches-en-ligne/',
#  'https://villefranche-sur-mer.fr/communication-presse/',
#  'https://villefranche-sur-mer.fr/magazines-municipaux/',
#  'https://villefranche-sur-mer.fr/villefranche-news/',
#  'https://villefranche-sur-mer.fr/la-ville-sengage-en-faveur-de-lenvironnement/',
#  'https://villefranche-sur-mer.fr/villefranche-sur-mer-et-sa-charte-de-larbre/',
#  'https://villefranche-sur-mer.fr/logo-charte-graphique/',
#  'https://villefranche-sur-mer.fr/presse-communiques-agendas/',
#  'https://villefranche-sur-mer.fr/presentation-service-urbanisme/',
#  'https://villefranche-sur-mer.fr/presentation-service-urbanisme/',
#  'https://villefranche-sur-mer.fr/plum-25102019/',
#  'https://www.nicecotedazur.org/habitat-urbanisme/evolution-du-plum/21-octobre-2021-modification-simplifi%C3%A9e-n-1-du-plum',
#  'https://www.nicecotedazur.org/habitat-urbanisme/r%C3%A9vision-g%C3%A9n%C3%A9rale-du-plum',
#  'https://www.nicecotedazur.org/services/urbanisme/plum/procedures-devolution-du-plum/',
#  'https://villefranche-sur-mer.fr/vie-locale/',
#  'https://villefranche-sur-mer.fr/famille/',
#  'https://www.ccas-villefranchesurmer.fr/la-petite-enfance/',
#  'https://www.ccas-villefranchesurmer.fr/bienvenue-au-ccas/les-seniors/',
#  'https://villefranche-sur-mer.fr/social-sante/',
#  'https://villefranche-sur-mer.fr/centre-communal-daction-sociale/',
#  'https://villefranche-sur-mer.fr/laide-sociale/',
#  'https://villefranche-sur-mer.fr/ehpad/',
#  'https://villefranche-sur-mer.fr/education/',
#  'https://villefranche-sur-mer.fr/etablissements-scolaires/',
#  'https://villefranche-sur-mer.fr/inscriptions-2024-2025/',
#  'https://villefranche-sur-mer.fr/listes-des-fournitures-scolaires/',
#  'https://villefranche-sur-mer.fr/scolabus/',
#  'https://villefranche-sur-mer.fr/restauration-scolaires/',
#  'https://villefranche-sur-mer.fr/portail-famille-de-villefranche-sur-mer/',
#  'https://villefranche-sur-mer.fr/vie-associative/',
#  'https://villefranche-sur-mer.fr/sports-loisirs/',
#  'https://villefranche-sur-mer.fr/demandes-de-subventions/',
#  'https://villefranche-sur-mer.fr/securite/',
#  'https://villefranche-sur-mer.fr/police-municipale/',
#  'https://villefranche-sur-mer.fr/voisins-vigilants/',
#  'https://villefranche-sur-mer.fr/videoprotection/',
#  'https://villefranche-sur-mer.fr/reserve-communale-de-securite-civile/',
#  'https://villefranche-sur-mer.fr/economie/',
#  'https://villefranche-sur-mer.fr/marches-a-villefranche/',
#  'https://villefranche-sur-mer.fr/occupation-du-domaine-public/',
#  'https://villefranche-sur-mer.fr/vie-quotidienne/',
#  'https://villefranche-sur-mer.fr/consultation-locale-sur-lamenagement-dun-sens-unique-de-circulation-en-centre-ville-convocation-des-electeurs-au-scrutin-du-samedi-4-decembre-2021/',
#  'https://villefranche-sur-mer.fr/parkings-2/',
#  'https://villefranche-sur-mer.fr/stationnement-en-zone-bleue/',
#  'https://villefranche-sur-mer.fr/service-voiturier-2024/',
#  'https://villefranche-sur-mer.fr/transports/',
#  'https://villefranche-sur-mer.fr/environnement/',
#  'https://villefranche-sur-mer.fr/villefranche-et-la-mer/',
#  'https://villefranche-sur-mer.fr/proprete-voirie/',
#  'https://villefranche-sur-mer.fr/label-villes-et-villages-fleuris/',
#  'https://villefranche-sur-mer.fr/culture/',
#  'https://villefranche-sur-mer.fr/faire-un-don-pour-le-bastion-de-la-turbie/',
#  'https://villefranche-sur-mer.fr/musees/',
#  'https://villefranche-sur-mer.fr/volti/',
#  'https://villefranche-sur-mer.fr/goetz-boumeester/',
#  'https://villefranche-sur-mer.fr/collection-roux/',
#  'https://villefranche-sur-mer.fr/24-eme-bca/',
#  'https://villefranche-sur-mer.fr/horaires-douverture/',
#  'https://villefranche-sur-mer.fr/boutique-des-musees/',
#  'https://villefranche-sur-mer.fr/animations-culturelles/',
#  'https://villefranche-sur-mer.fr/animations-au-coeur-des-musees/',
#  'https://villefranche-sur-mer.fr/atelier-municipal-de-sculptures/',
#  'https://villefranche-sur-mer.fr/expositions-temporaires/',
#  'https://villefranche-sur-mer.fr/chapelle-saint-elme/',
#  'https://villefranche-sur-mer.fr/chapelle-sainte-elisabeth/',
#  'https://villefranche-sur-mer.fr/villefranche-patrimoine/',
#  'https://villefranche-sur-mer.fr/villefranche-et-le-cinema/',
#  'https://villefranche-sur-mer.fr/cocteau-et-villefranche/',
#  'https://villefranche-sur-mer.fr/villefranche-et-les-russes/',
#  'https://villefranche-sur-mer.fr/villefranche-et-les-americains/',
#  'https://villefranche-sur-mer.fr/centenaire-1914-1918/',
#  'https://villefranche-sur-mer.fr/sports-loisirs/',
#  'https://villefranche-sur-mer.fr/associations-sportives/',
#  'https://villefranche-sur-mer.fr/associations-culturelles/',
#  'https://villefranche-sur-mer.fr/associations-parents-eleves/',
#  'https://villefranche-sur-mer.fr/associations-patriotiques/',
#  'https://villefranche-sur-mer.fr/associations-caritatives/',
#  'https://villefranche-sur-mer.fr/associations-patrimoine-environnement/',
#  'https://villefranche-sur-mer.fr/associations-diverses/',
#  'https://villefranche-sur-mer.fr/equipements/',
#  'https://villefranche-sur-mer.fr/complexe-multisports-de-la-barmassa/',
#  'https://villefranche-sur-mer.fr/gymnase-des-glacis/',
#  'https://villefranche-sur-mer.fr/stade-de-football-antoine-bonifaci/',
#  'https://villefranche-sur-mer.fr/les-terrains-de-tennis/',
#  'https://villefranche-sur-mer.fr/gymnase-de-la-corne-dor/',
#  'https://villefranche-sur-mer.fr/associations-de-plaisanciers/',
#  'http://www.ccas-villefranchesurmer.fr/',
#  'https://www.explorenicecotedazur.com/villefranche-sur-mer/',
#  'https://villefranche-sur-mer.fr/events/',
#  'https://villefranche-sur-mer.fr/nous-contacter/',
#  'https://villefranche-sur-mer.fr/',
#  'https://villefranche-sur-mer.fr/mairie/',
#  'https://villefranche-sur-mer.fr/conseil-municipal/',
#  'https://villefranche-sur-mer.fr/deliberations-du-conseil-municipal/',
#  'https://villefranche-sur-mer.fr/comptes-rendus-des-conseils-municipaux/',
#  'https://villefranche-sur-mer.fr/documents-budgetaires/',
#  'https://villefranche-sur-mer.fr/actes-reglementaires/',
#  'https://villefranche-sur-mer.fr/actes-reglementaires-2/',
#  'https://villefranche-sur-mer.fr/deliberations-2/',
#  'https://villefranche-sur-mer.fr/le-maire/',
#  'https://villefranche-sur-mer.fr/les-elus-municipaux/',
#  'https://villefranche-sur-mer.fr/services-municipaux/',
#  'https://villefranche-sur-mer.fr/organigramme-des-services/',
#  'https://villefranche-sur-mer.fr/services-administratifs/',
#  'https://villefranche-sur-mer.fr/services-techniques/',
#  'https://villefranche-sur-mer.fr/le-service-des-mouillages/',
#  'https://villefranche-sur-mer.fr/marches-publics/',
#  'https://villefranche-sur-mer.fr/enquetes-publiques/',
#  'https://villefranche-sur-mer.fr/demarches-administratives/',
#  'https://villefranche-sur-mer.fr/vous-etes-proprietaire-dun-logement-et-vous-desirez-le-proposer-en-location-meublee-touristique-vous-etes-proprietaire-ou-locataire-et-vous-desirez-transformer-un-logement-pour-y-exercer-vo/',
#  'https://villefranche-sur-mer.fr/abattage-arbre-ou-defrichement/',
#  'https://villefranche-sur-mer.fr/ouverture-de-lespace-france-services/',
#  'https://villefranche-sur-mer.fr/etat-civil/',
#  'https://villefranche-sur-mer.fr/demarches-en-ligne/',
#  'https://villefranche-sur-mer.fr/communication-presse/',
#  'https://villefranche-sur-mer.fr/magazines-municipaux/',
#  'https://villefranche-sur-mer.fr/villefranche-news/',
#  'https://villefranche-sur-mer.fr/la-ville-sengage-en-faveur-de-lenvironnement/',
#  'https://villefranche-sur-mer.fr/villefranche-sur-mer-et-sa-charte-de-larbre/',
#  'https://villefranche-sur-mer.fr/logo-charte-graphique/',
#  'https://villefranche-sur-mer.fr/presse-communiques-agendas/',
#  'https://villefranche-sur-mer.fr/presentation-service-urbanisme/',
#  'https://villefranche-sur-mer.fr/presentation-service-urbanisme/',
#  'https://villefranche-sur-mer.fr/plum-25102019/',
#  'https://www.nicecotedazur.org/habitat-urbanisme/evolution-du-plum/21-octobre-2021-modification-simplifi%C3%A9e-n-1-du-plum',
#  'https://www.nicecotedazur.org/habitat-urbanisme/r%C3%A9vision-g%C3%A9n%C3%A9rale-du-plum',
#  'https://www.nicecotedazur.org/services/urbanisme/plum/procedures-devolution-du-plum/',
#  'https://villefranche-sur-mer.fr/vie-locale/',
#  'https://villefranche-sur-mer.fr/famille/',
#  'https://www.ccas-villefranchesurmer.fr/la-petite-enfance/',
#  'https://www.ccas-villefranchesurmer.fr/bienvenue-au-ccas/les-seniors/',
#  'https://villefranche-sur-mer.fr/social-sante/',
#  'https://villefranche-sur-mer.fr/centre-communal-daction-sociale/',
#  'https://villefranche-sur-mer.fr/laide-sociale/',
#  'https://villefranche-sur-mer.fr/ehpad/',
#  'https://villefranche-sur-mer.fr/education/',
#  'https://villefranche-sur-mer.fr/etablissements-scolaires/',
#  'https://villefranche-sur-mer.fr/inscriptions-2024-2025/',
#  'https://villefranche-sur-mer.fr/listes-des-fournitures-scolaires/',
#  'https://villefranche-sur-mer.fr/scolabus/',
#  'https://villefranche-sur-mer.fr/restauration-scolaires/',
#  'https://villefranche-sur-mer.fr/portail-famille-de-villefranche-sur-mer/',
#  'https://villefranche-sur-mer.fr/vie-associative/',
#  'https://villefranche-sur-mer.fr/sports-loisirs/',
#  'https://villefranche-sur-mer.fr/demandes-de-subventions/',
#  'https://villefranche-sur-mer.fr/securite/',
#  'https://villefranche-sur-mer.fr/police-municipale/',
#  'https://villefranche-sur-mer.fr/voisins-vigilants/',
#  'https://villefranche-sur-mer.fr/videoprotection/',
#  'https://villefranche-sur-mer.fr/reserve-communale-de-securite-civile/',
#  'https://villefranche-sur-mer.fr/economie/',
#  'https://villefranche-sur-mer.fr/marches-a-villefranche/',
#  'https://villefranche-sur-mer.fr/occupation-du-domaine-public/',
#  'https://villefranche-sur-mer.fr/vie-quotidienne/',
#  'https://villefranche-sur-mer.fr/consultation-locale-sur-lamenagement-dun-sens-unique-de-circulation-en-centre-ville-convocation-des-electeurs-au-scrutin-du-samedi-4-decembre-2021/',
#  'https://villefranche-sur-mer.fr/parkings-2/',
#  'https://villefranche-sur-mer.fr/stationnement-en-zone-bleue/',
#  'https://villefranche-sur-mer.fr/service-voiturier-2024/',
#  'https://villefranche-sur-mer.fr/transports/',
#  'https://villefranche-sur-mer.fr/environnement/',
#  'https://villefranche-sur-mer.fr/villefranche-et-la-mer/',
#  'https://villefranche-sur-mer.fr/proprete-voirie/',
#  'https://villefranche-sur-mer.fr/label-villes-et-villages-fleuris/',
#  'https://villefranche-sur-mer.fr/culture/',
#  'https://villefranche-sur-mer.fr/faire-un-don-pour-le-bastion-de-la-turbie/',
#  'https://villefranche-sur-mer.fr/musees/',
#  'https://villefranche-sur-mer.fr/volti/',
#  'https://villefranche-sur-mer.fr/goetz-boumeester/',
#  'https://villefranche-sur-mer.fr/collection-roux/',
#  'https://villefranche-sur-mer.fr/24-eme-bca/',
#  'https://villefranche-sur-mer.fr/horaires-douverture/',
#  'https://villefranche-sur-mer.fr/boutique-des-musees/',
#  'https://villefranche-sur-mer.fr/animations-culturelles/',
#  'https://villefranche-sur-mer.fr/animations-au-coeur-des-musees/',
#  'https://villefranche-sur-mer.fr/atelier-municipal-de-sculptures/',
#  'https://villefranche-sur-mer.fr/expositions-temporaires/',
#  'https://villefranche-sur-mer.fr/chapelle-saint-elme/',
#  'https://villefranche-sur-mer.fr/chapelle-sainte-elisabeth/',
#  'https://villefranche-sur-mer.fr/villefranche-patrimoine/',
#  'https://villefranche-sur-mer.fr/villefranche-et-le-cinema/',
#  'https://villefranche-sur-mer.fr/cocteau-et-villefranche/',
#  'https://villefranche-sur-mer.fr/villefranche-et-les-russes/',
#  'https://villefranche-sur-mer.fr/villefranche-et-les-americains/',
#  'https://villefranche-sur-mer.fr/centenaire-1914-1918/',
#  'https://villefranche-sur-mer.fr/sports-loisirs/',
#  'https://villefranche-sur-mer.fr/associations-sportives/',
#  'https://villefranche-sur-mer.fr/associations-culturelles/',
#  'https://villefranche-sur-mer.fr/associations-parents-eleves/',
#  'https://villefranche-sur-mer.fr/associations-patriotiques/',
#  'https://villefranche-sur-mer.fr/associations-caritatives/',
#  'https://villefranche-sur-mer.fr/associations-patrimoine-environnement/',
#  'https://villefranche-sur-mer.fr/associations-diverses/',
#  'https://villefranche-sur-mer.fr/equipements/',
#  'https://villefranche-sur-mer.fr/complexe-multisports-de-la-barmassa/',
#  'https://villefranche-sur-mer.fr/gymnase-des-glacis/',
#  'https://villefranche-sur-mer.fr/stade-de-football-antoine-bonifaci/',
#  'https://villefranche-sur-mer.fr/les-terrains-de-tennis/',
#  'https://villefranche-sur-mer.fr/gymnase-de-la-corne-dor/',
#  'https://villefranche-sur-mer.fr/associations-de-plaisanciers/',
#  'http://www.ccas-villefranchesurmer.fr/',
#  'https://www.explorenicecotedazur.com/villefranche-sur-mer/',
#  'https://villefranche-sur-mer.fr/events/',
#  'https://villefranche-sur-mer.fr/nous-contacter/',
#  '#',
#  '#',
#  '#',
#  'https://villefranche-sur-mer.fr/retrouvez-le-conseil-municipal-du-20-janvier-2025/',
#  'https://villefranche-sur-mer.fr/retrouvez-le-conseil-municipal-du-20-janvier-2025/',
#  'https://villefranche-sur-mer.fr/retrouvez-le-conseil-municipal-du-20-janvier-2025/#respond',
#  'https://villefranche-sur-mer.fr/floralies-recherche-dexposants/',
#  'https://villefranche-sur-mer.fr/floralies-recherche-dexposants/',
#  'https://villefranche-sur-mer.fr/floralies-recherche-dexposants/#respond',
#  'https://villefranche-sur-mer.fr/assistez-a-la-projection-debat-ocean-indien-la-mission-oceanographique-organisee-par-linstitut-de-la-mer-de-villefranche/',
#  'https://villefranche-sur-mer.fr/assistez-a-la-projection-debat-ocean-indien-la-mission-oceanographique-organisee-par-linstitut-de-la-mer-de-villefranche/',
#  'https://villefranche-sur-mer.fr/assistez-a-la-projection-debat-ocean-indien-la-mission-oceanographique-organisee-par-linstitut-de-la-mer-de-villefranche/#respond',
#  'https://villefranche-sur-mer.fr/combat-naval-fleuri-a-villefranche-sur-mer-le-17-fevrier/',
#  'https://villefranche-sur-mer.fr/combat-naval-fleuri-a-villefranche-sur-mer-le-17-fevrier/',
#  'https://villefranche-sur-mer.fr/combat-naval-fleuri-a-villefranche-sur-mer-le-17-fevrier/#respond',
#  'https://villefranche-sur-mer.fr/2eme-phase-des-travaux-du-parking-wilson-du-lundi-13-au-lundi-20-janvier/',
#  'https://villefranche-sur-mer.fr/2eme-phase-des-travaux-du-parking-wilson-du-lundi-13-au-lundi-20-janvier/',
#  'https://villefranche-sur-mer.fr/2eme-phase-des-travaux-du-parking-wilson-du-lundi-13-au-lundi-20-janvier/#respond',
#  'https://villefranche-sur-mer.fr/le-parking-des-marinieres-est-ferme-pour-travaux-jusquau-15-mars/',
#  'https://villefranche-sur-mer.fr/le-parking-des-marinieres-est-ferme-pour-travaux-jusquau-15-mars/',
#  'https://villefranche-sur-mer.fr/le-parking-des-marinieres-est-ferme-pour-travaux-jusquau-15-mars/#respond',
#  'https://villefranche-sur-mer.fr/magazines-municipaux/',
#  'http://villefranche-sur-mer.us11.list-manage.com/subscribe?u=c37e60d0fd1501e8c3f82c91d&id=0f324239a1',
#  'https://villefranche-sur-mer.fr/wp-content/uploads/2023/01/0912_001.pdf',
#  'https://villefranche-sur-mer.fr/demarches-en-ligne/',
#  'https://villefranche-sur-mer.fr/marches-publics/',
#  'https://villefranche-sur-mer.fr/occupation-du-domaine-public/',
#  'https://villefranche-sur-mer.fr/nous-contacter/',
#  'https://villefranche-sur-mer.fr/telepaiements-dgfip-une-boite-a-outils-performante/',
#  'https://villefranche-sur-mer.fr/la-grande-emission-azur-tv-juillet-2015/',
#  'https://villefranche-sur-mer.fr/phototheque/',
#  'https://villefranche-sur-mer.fr/videotheque/',
#  'https://sivom-villefranche.mediatheque06.fr/',
#  'http://www.nicecotedazur.org/',
#  'http://usagers.ville-nice.fr/RAA/Accueil.aspx?RAA=02-2017-1',
#  'https://www.departement06.fr/',
#  'http://www.sivom-villefranche.org/',
#  'https://villefranche-sur-mer.fr/reglement-general-sur-la-protection-des-donnees/',
#  'https://villefranche-sur-mer.fr/nous-contacter/',
#  'https://villefranche-sur-mer.fr/plan-du-site/',
#  'https://www.facebook.com/Villefranche.sur.Mer',
#  'https://twitter.com/Villefranche06',
#  'https://www.youtube.com/channel/UC5BVjKgPTMrIhs1EBXEEtHw',
#  'https://plus.google.com/b/115561674342366306734/115561674342366306734/posts',
#  '#',
#  'http://instagram.com/villede_villefranche_sur_mer',
#  '#']

# %%
# Generate a system prompt for link relevance selection
link_system_prompt = "You are provided with a list of links found on a webpage. \
You can decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in those examples:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""
link_system_prompt += """
{
    "links": [
        {"type": "contact page", "url": "https://full.url/goes/here/contact"},
        {"type": "social links page": "url": "https://another.full.url/social"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You can decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, a Company page, or Careers/Jobs pages.
# You should respond in JSON as in those examples:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }
#
# {
#     "links": [
#         {"type": "contact page", "url": "https://full.url/goes/here/contact"},
#         {"type": "social links page": "url": "https://another.full.url/social"}
#     ]
# }

# %%
# Construct a user prompt with website links for AI processing
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(vlf))
# Out:
# Here is the list of links on the website of https://villefranche-sur-mer.fr - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://villefranche-sur-mer.fr
# https://villefranche-sur-mer.fr/
# https://villefranche-sur-mer.fr/mairie/
# https://villefranche-sur-mer.fr/conseil-municipal/
# https://villefranche-sur-mer.fr/deliberations-du-conseil-municipal/
# https://villefranche-sur-mer.fr/comptes-rendus-des-conseils-municipaux/
# https://villefranche-sur-mer.fr/documents-budgetaires/
# https://villefranche-sur-mer.fr/actes-reglementaires/
# https://villefranche-sur-mer.fr/actes-reglementaires-2/
# https://villefranche-sur-mer.fr/deliberations-2/
# https://villefranche-sur-mer.fr/le-maire/
# https://villefranche-sur-mer.fr/les-elus-municipaux/
# https://villefranche-sur-mer.fr/services-municipaux/
# https://villefranche-sur-mer.fr/organigramme-des-services/
# https://villefranche-sur-mer.fr/services-administratifs/
# https://villefranche-sur-mer.fr/services-techniques/
# http://www.sivom-villefranche.org/
# https://villefranche-sur-mer.fr/reglement-general-sur-la-protection-des-donnees/
# https://villefranche-sur-mer.fr/nous-contacter/
# https://villefranche-sur-mer.fr/plan-du-site/
# https://www.facebook.com/Villefranche.sur.Mer
# https://twitter.com/Villefranche06
# https://www.youtube.com/channel/UC5BVjKgPTMrIhs1EBXEEtHw
# https://plus.google.com/b/115561674342366306734/115561674342366306734/posts
# #
# http://instagram.com/villede_villefranche_sur_mer
# #

# %%
# Retrieve and filter relevant links from a website using OpenAI
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/deepseek-ai/DeepSeek-R1',
#  '/hexgrad/Kokoro-82M',
#  '/deepseek-ai/DeepSeek-R1-Distill-Qwen-32B',
#  '/deepseek-ai/DeepSeek-R1-Zero',
#  '/deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B',
#  '/models',
#  '/spaces/hexgrad/Kokoro-TTS',
#  '/spaces/tencent/Hunyuan3D-2',
#  '/spaces/lllyasviel/iclight-v2',
#  '/spaces/JeffreyXiang/TRELLIS',
#  '/spaces/webml-community/deepseek-r1-webgpu',
#  '/spaces',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/HumanLLMs/Human-Like-DPO-Dataset',
#  '/datasets/bespokelabs/Bespoke-Stratos-17k',
#  '/datasets/cais/hle',
#  '/datasets/yale-nlp/MMVU',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/peft',
#  '/docs/transformers.js',
#  '/docs/timm',
#  '/docs/trl',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'docs page', 'url': 'https://huggingface.co/docs'},
#   {'type': 'social links page', 'url': 'https://twitter.com/huggingface'},
#   {'type': 'social links page',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %%
# Collect comprehensive details from a website's landing page and relevant links
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'contact page', 'url': 'https://discuss.huggingface.co'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Trending on
# this week
# Models
# deepseek-ai/DeepSeek-R1
# Updated
# 1 day ago
# •
# 69.6k
# •
# 2.21k
# hexgrad/Kokoro-82M
# Updated
# 2 days ago
# •
# 33.9k
# •
# 2.32k
# deepseek-ai/DeepSeek-R1-Distill-Qwen-32B
# Updated
# 1 day ago
# •
# 75.9k
# •
# 429
# deepseek-ai/DeepSeek-R1-Zero
# Updated
# 1 day ago
# •
# 4.48k
# •
# 395
# deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B
# Updated
# 1 day ago
# •
# 70.1k
# •
# 328
# Browse 400k+ models
# Spaces
# Running
# on
# Zero
# 1.47k
# ❤️
# Kokoro TTS
# Now in 5 languages!
# Running
# on
# Zero
# 312
# 🌍
# Hunyuan3D-2.0
# Text-to-3D and Image-to-3D Generation
# Running
# on
# Zero
# 1.92k
# 📈
# IC Light V2
# Running
# on
# Zero
# 3.28k
# 🏢
# TRELLIS
# Scalable and Versatile 3D Generation from images
# Running
# 207
# 🧠
# DeepSeek-R1 WebGPU
# Next-generation reasoning model that runs locally in-browser
# Browse 150k+ applications
# Datasets
# fka/awesome-chatgpt-prompts
# Updated
# 19 days ago
# •
# 6.89k
# •
# 7.06k
# HumanLLMs/Human-Like-DPO-Dataset
# Updated
# 12 days ago
# •
# 1.62k
# •
# 158
# bespokelabs/Bespoke-Stratos-17k
# Updated
# about 15 hours ago
# •
# 1.9k
# •
# 58
# cais/hle
# Updated
# 1 day ago
# •
# 406
# •
# 55
# yale-nlp/MMVU
# Updated
# 2 days ago
# •
# 1.31k
# •
# 47
# Browse 100k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 378 models
# •
# 1.94k followers
# AI at Meta
# Enterprise
# company
# •
# 2.06k models
# •
# 4.24k followers
# Amazon Web Services
# company
# •
# 20 models
# •
# 2.58k followers
# Google
# company
# •
# 913 models
# •
# 6.8k followers
# Intel
# company
# •
# 218 models
# •
# 2.17k followers
# Microsoft
# company
# •
# 353 models
# •
# 7.66k followers
# Grammarly
# company
# •
# 10 models
# •
# 115 followers
# Writer
# Enterprise
# company
# •
# 18 models
# •
# 200 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 137,968
# State-of-the-art ML for Pytorch, TensorFlow, and JAX.
# Diffusers
# 27,265
# State-of-the-art diffusion models for image and audio generation in PyTorch.
# Safetensors
# 3,019
# Simple, safe way to store and distribute neural networks weights safely and quickly.
# Hub Python Library
# 2,245
# Client library for the HF Hub: manage repositories from your Python runtime.
# Tokenizers
# 9,275
# Fast tokenizers, optimized for both research and production.
# PEFT
# 17,053
# Parameter efficient finetuning methods for large models.
# Transformers.js
# 12,672
# State-of-the-art Machine Learning for the web. Run Transformers directly in your browser, with no need for a server.
# timm
# 32,990
# State-of-the-art computer vision models, layers, optimizers, training/evaluation, and utilities.
# TRL
# 10,722
# Train transformer language models with reinforcement learning.
# Datasets
# 19,483
# Access and share datasets for computer vision, audio, and NLP tasks.
# Text Generation Inference
# 9,632
# Toolkit to serve Large Language Models.
# Accelerate
# 8,201
# Easily train and use PyTorch models with multi-GPU, TPU, mixed-precision.
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 14,054
# AI & ML interests
# The AI community building the future.
# Recent Activity
# nielsr
# updated
# a dataset
# about 2 hours ago
# huggingface/community-science-merged
# stevhliu
# updated
# a dataset
# about 15 hours ago
# huggingface/documentation-images
# qubvel-hf
# new
# activity
# about 24 hours ago
# huggingface/documentation-images:
# Dab Detr model card images
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# 4 days ago
# •
# 29
# Team members
# 224
# +190
# +177
# +156
# +146
# +126
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 300k
# •
# 36
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 14.3M
# •
# •
# 603
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 611k
# •
# 163
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 6.73M
# •
# •
# 674
# spaces
# 23
# Sort:
# 		Recently updated
# pinned
# Running
# 60
# 📈
# Number Tokenization Blog
# Running
# 515
# 😻
# Open Source Ai Year In Review 2024
# What happened in open-source AI this year, and what’s next?
# Running
# 47
# 🔋
# Inference Playground
# Running
# 206
# ⚡
# paper-central
# Running
# on
# TPU v5e
# 8
# 💬
# Keras Chatbot Battle
# Running
# 102
# ⚡
# Modelcard Creator
# Expand 23
# 							spaces
# models
# 18
# Sort:
# 		Recently updated
# huggingface/test-gating-group-2
# Updated
# Dec 17, 2024
# huggingface/test-gating-group-1
# Updated
# Dec 17, 2024
# huggingface/timesfm-tourism-monthly
# Updated
# Dec 9, 2024
# •
# 9
# •
# 1
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 3.27k
# •
# 54
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 18
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 1.68k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 276
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 1.51k
# •
# 5
# huggingface/time-series-transformer-tourism-monthly
# Updated
# Feb 23, 2023
# •
# 1.85k
# •
# 18
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 73
# •
# 3
# Expand 18
# 							models
# datasets
# 32
# Sort:
# 		Recently updated
# huggingface/community-science-merged
# Viewer
# •
# Updated
# about 2 hours ago
# •
# 5.3k
# •
# 371
# •
# 3
# huggingface/documentation-images
# Viewer
# •
# Updated
# about 15 hours ago
# •
# 50
# •
# 2.53M
# •
# 47
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 1 day ago
# •
# 1.55k
# •
# 456
# •
# 15
# huggingface/policy-docs
# Updated
# 7 days ago
# •
# 1.88k
# •
# 7
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# 11 days ago
# •
# 64
# •
# 429
# •
# 5
# huggingface/paper-central-data
# Viewer
# •
# Updated
# 20 days ago
# •
# 124k
# •
# 469
# •
# 8
# huggingface/community-science-paper-v2
# Viewer
# •
# Updated
# Dec 22, 2024
# •
# 5.03k
# •
# 67
# •
# 7
# huggingface/my-distiset-3f5a230e
# Updated
# Nov 21, 2024
# •
# 25
# huggingface/cookbook-images
# Viewer
# •
# Updated
# Nov 14, 2024
# •
# 1
# •
# 34.4k
# •
# 6
# huggingface/vllm-metadata
# Updated
# Oct 8, 2024
# •
# 18
# Expand 32
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# SmolVLM Grows Smaller – Introducing the 250M & 500M Models!
# By
# andito
# January 23, 2025
# •
# 58
# Community Articles
# view all
# Failure Modes of OpenAI Operator
# By
# Zengyi-Qin
# •
# about 1 hour ago
# •
# 2
# DeepSeek R1 on how to build conscious AGI
# By
# KnutJaegersberg
# •
# about 5 hours ago
# •
# 2
# **Topic 24: What is Cosmos World Foundation Model Platform?**
# By
# Kseniase
# •
# about 20 hours ago
# •
# 4
# Explore, Curate and Vector Search Any Hugging Face Dataset with Nomic Atlas
# By
# MaxNomic
# •
# about 20 hours ago
# •
# 23
# Mastering Long Contexts in LLMs with KVPress
# By
# nvidia
# •
# 1 day ago
# •
# 49
# Distributed SFT with trl and DeepSpeed Part 1: Starting Locally
# By
# jlzhou
# •
# 1 day ago
# Optimizing Pretraining Data Mixes with LLM-Estimated Utility
# By
# WillHeld
# •
# 2 days ago
# •
# 2
# Exploring Synthetic Data Generation with DataDreamer
# By
# asoria
# •
# 3 days ago
# •
# 4
# Supercharging AI Agents in KaibanJS with Serper Search
# By
# darielnoel
# •
# 4 days ago
# PEFT: Métodos de Fine-Tuning Eficiente para LLMs
# By
# samuellimabraz
# •
# 4 days ago
# The SOTA Text-to-speech and Zero Shot Voice cloning model that no one knows about...
# By
# srinivasbilla
# •
# 4 days ago
# •
# 35
# 🌁#84: Could Program Synthesis Unlock AGI?
# By
# Kseniase
# •
# 4 days ago
# •
# 4
# FuseO1-Preview: System-II Reasoning Fusion of LLMs
# By
# Wanfq
# •
# 4 days ago
# •
# 8
# Yay! Organizations can now publish blog Articles
# By
# huggingface
# •
# 4 days ago
# •
# 29
# Computational Model for Symbolic Representations: An Interaction Framework for Human-AI Collaboration
# By
# Severian
# •
# 4 days ago
# •
# 1
# Fine-tune ModernBERT for RAG with Synthetic Data
# By
# sdiazlor
# •
# 4 days ago
# •
# 28
# A Beginner-Friendly PyTorch Tutorial: Build and Train Your First Model
# By
# dvgodoy
# •
# 4 days ago
# •
# 3
# So, what is general intelligence?
# By
# KnutJaegersberg
# •
# 4 days ago
# •
# 2
# Why PyThagorean? 🐍
# By
# prithivMLmods
# •
# 4 days ago
# •
# 6
# Simplifying Alignment: From RLHF to Direct Preference Optimization (DPO)
# By
# ariG23498
# •
# 5 days ago
# •
# 13
# Hugging Face and FriendliAI partner to supercharge model deployment on the Hub
# By
# ajshinfai
# January 22, 2025
# •
# 28
# Timm ❤️ Transformers: Use any timm model with transformers
# By
# ariG23498
# January 16, 2025
# •
# 33
# Introducing multi-backends (TRT-LLM, vLLM) support for Text Generation Inference
# By
# mfuntowicz
# January 16, 2025
# •
# 59
# Train 400x faster Static Embedding Models with Sentence Transformers
# By
# tomaarsen
# January 15, 2025
# •
# 120
# Run ComfyUI workflows for free on Spaces
# By
# multimodalart
# January 14, 2024
# •
# 41
# AI Agents Are Here. What Now?
# By
# meg
# January 13, 2025
# •
# 53
# Visual Document Retrieval Goes Multilingual
# By
# marco
# January 10, 2025
# guest
# •
# 61
# CO₂ Emissions and Models Performance: Insights from the Open LLM Leaderboard
# By
# alozowski
# January 9, 2025
# •
# 14
# Introducing smolagents: simple agents that write actions in code.
# By
# m-ric
# December 31, 2024
# •
# 519
# Visualize and understand GPU memory in PyTorch
# By
# qgallouedec
# December 24, 2024
# •
# 170
# Controlling Language Model Generation with NVIDIA's LogitsProcessorZoo
# By
# ariG23498
# December 23, 2024
# •
# 36
# Evaluating Audio Reasoning with Big Bench Audio
# By
# mhillsmith
# December 20, 2024
# guest
# •
# 17
# Finally, a Replacement for BERT: Introducing ModernBERT
# By
# bwarner
# December 19, 2024
# guest
# •
# 501
# Bamba: Inference-Efficient Hybrid Mamba2 Model
# By
# Linsong-C
# December 18, 2024
# guest
# •
# 40
# Previous
# 1
# 2
# 3
# ...
# 37
# Next
# Community Articles
# view all
# Failure Modes of OpenAI Operator
# By
# Zengyi-Qin
# •
# about 1 hour ago
# •
# 2
# DeepSeek R1 on how to build conscious AGI
# By
# KnutJaegersberg
# •
# about 5 hours ago
# •
# 2
# **Topic 24: What is Cosmos World Foundation Model Platform?**
# By
# Kseniase
# •
# about 20 hours ago
# •
# 4
# Explore, Curate and Vector Search Any Hugging Face Dataset with Nomic Atlas
# By
# MaxNomic
# •
# about 20 hours ago
# •
# 23
# Mastering Long Contexts in LLMs with KVPress
# By
# nvidia
# •
# 1 day ago
# •
# 49
# Distributed SFT with trl and DeepSpeed Part 1: Starting Locally
# By
# jlzhou
# •
# 1 day ago
# Optimizing Pretraining Data Mixes with LLM-Estimated Utility
# By
# WillHeld
# •
# 2 days ago
# •
# 2
# Exploring Synthetic Data Generation with DataDreamer
# By
# asoria
# •
# 3 days ago
# •
# 4
# Supercharging AI Agents in KaibanJS with Serper Search
# By
# darielnoel
# •
# 4 days ago
# PEFT: Métodos de Fine-Tuning Eficiente para LLMs
# By
# samuellimabraz
# •
# 4 days ago
# The SOTA Text-to-speech and Zero Shot Voice cloning model that no one knows about...
# By
# srinivasbilla
# •
# 4 days ago
# •
# 35
# 🌁#84: Could Program Synthesis Unlock AGI?
# By
# Kseniase
# •
# 4 days ago
# •
# 4
# FuseO1-Preview: System-II Reasoning Fusion of LLMs
# By
# Wanfq
# •
# 4 days ago
# •
# 8
# Yay! Organizations can now publish blog Articles
# By
# huggingface
# •
# 4 days ago
# •
# 29
# Computational Model for Symbolic Representations: An Interaction Framework for Human-AI Collaboration
# By
# Severian
# •
# 4 days ago
# •
# 1
# Fine-tune ModernBERT for RAG with Synthetic Data
# By
# sdiazlor
# •
# 4 days ago
# •
# 28
# A Beginner-Friendly PyTorch Tutorial: Build and Train Your First Model
# By
# dvgodoy
# •
# 4 days ago
# •
# 3
# So, what is general intelligence?
# By
# KnutJaegersberg
# •
# 4 days ago
# •
# 2
# Why PyThagorean? 🐍
# By
# prithivMLmods
# •
# 4 days ago
# •
# 6
# Simplifying Alignment: From RLHF to Direct Preference Optimization (DPO)
# By
# ariG23498
# •
# 5 days ago
# •
# 13
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# contact page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# New battle in AI field
# Beginners
# 1
# 12
# January 24, 2025
# Various AI Models
# Beginners
# 1
# 4
# January 24, 2025
# The Best Approach for Weighted Multilabel Classification
# 🤗Transformers
# 1
# 7
# January 24, 2025
# How can I replace modules in a pretrained model?
# 🤗Transformers
# 4
# 3891
# January 24, 2025
# Understanding where model weights are stored for research project on AI openness
# Research
# 1
# 12
# January 24, 2025
# How do I format the column mapping on the autotrainer?
# Beginners
# 1
# 3
# January 24, 2025
# RuntimeError: result type Float can't be cast to the desired output type Long
# 🤗Transformers
# 1
# 5
# January 24, 2025
# Download and load fine-tuned model locally (VS Code)
# Beginners
# 3
# 4095
# January 24, 2025
# Implimentation of Stopping Criteria List
# Beginners
# 24
# 28507
# January 24, 2025
# Codebase Embedding
# Beginners
# 3
# 19
# January 24, 2025
# How to obtain faster Inference Endpoint
# Inference Endpoints on the Hub
# 4
# 18
# January 24, 2025
# Extracting attention mask from Qwen model
# Beginners
# 1
# 8
# January 24, 2025
# I keep getting error when attempting to connect to some domains e.g, web.whatsapp socket, facebook etc
# Spaces
# 3
# 8
# January 24, 2025
# Living Logic: A Framework for Systemic Healing and Ethical AI
# Beginners
# 1
# 8
# January 23, 2025
# Manifesto for Unapologetic Ethics: A New Covenant for the Age of Systemic Collapse and Exponential Innovation
# Beginners
# 0
# 13
# January 23, 2025
# Dimension Error After Prompt-tuning the Gemma2 model
# Beginners
# 2
# 9
# January 23, 2025
# How to Pass Image-Based Math/Geometry Problems to an LLM Without a Vision Model? (OCR Not Sufficient)
# Beginners
# 1
# 6
# January 24, 2025
# Triggering Space Updates on Dataset Changes
# Spaces
# 1
# 9
# January 23, 2025
# Fine-tuning "reasoning" models
# Models
# 1
# 33
# January 23, 2025
# Which LLM Works Best for Prompt and Response Generation in Chinese (Simplified and Traditional)
# Languages at Hugging Face
# 3
# 25
# January 23, 2025
# Cannot install Faiss in Google Collab
# 🤗Datasets
# 4
# 1597
# January 24, 2025
# Issue when trying to switch between different LoRa adapters
# 🧨 Diffusers
# 1
# 10
# January 22, 2025
# Best LLMs that can run on 4gb VRAM
# Beginners
# 2
# 68
# January 22, 2025
# How To Fine-Tune Models for Better NSFW AI Detection?
# Beginners
# 7
# 832
# January 23, 2025
# Huggingface documents tool calling question
# Beginners
# 3
# 17
# January 23, 2025
# Using device_map='auto' for training
# 🤗Accelerate
# 5
# 29697
# January 24, 2025
# Custom dataset maskformer
# Intermediate
# 15
# 32
# January 18, 2025
# The state_dict export by peft.get_peft_model_state_dict doesn't contain adapter name
# 🤗Transformers
# 7
# 7
# January 22, 2025
# Accessing a model with model.generate via remote only
# 🤗Transformers
# 1
# 7
# January 22, 2025
# NLP for Summarization and classification
# Beginners
# 4
# 28
# January 22, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# Pro Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Higher rate limits for serverless inference
# Get early access to upcoming features
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 5x more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# TPU v5e 1x1
# 22 vCPU
# 44 GB
# Google TPU v5e
# 16 GB
# $1.20
# TPU v5e 2x2
# 110 vCPU
# 186 GB
# Google TPU v5e
# 64 GB
# $4.75
# TPU v5e 2x4
# 220 vCPU
# 380 GB
# Google TPU v5e
# 128 GB
# $9.50
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# Pro Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get Pro
# ($9/month)
# ZeroGPU
# : Get 5x usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with A100 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Dataset Viewer
# : Activate it on private datasets
# Inference API
# : Get x20 higher rate limits on Serverless API
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 276 models
# •
# 11.5k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 275 followers
# Together
# Enterprise
# company
# •
# 31 models
# •
# 486 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 115 followers
# Bloomberg
# Enterprise
# company
# •
# 2 models
# •
# 142 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 372 followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 64 models
# •
# 1.15k followers
# Chegg Inc
# Enterprise
# company
# •
# 80 followers
# Stability AI
# Enterprise
# company
# •
# 99 models
# •
# 12.6k followers
# Liberty Mutual
# Enterprise
# company
# •
# 43 followers
# Nutanix
# Enterprise
# company
# •
# 247 models
# •
# 43 followers
# MiniMax
# Enterprise
# company
# •
# 2 models
# •
# 466 followers
# BCG X
# Enterprise
# company
# •
# 31 followers
# Qualcomm
# Enterprise
# company
# •
# 156 models
# •
# 400 followers
# Meta Llama
# Enterprise
# company
# •
# 57 models
# •
# 21.1k followers
# Orange
# Enterprise
# company
# •
# 4 models
# •
# 161 followers
# Arm
# Enterprise
# company
# •
# 129 followers
# Writer
# Enterprise
# company
# •
# 18 models
# •
# 200 followers
# Fidelity Investments
# Enterprise
# company
# •
# 120 followers
# Jusbrasil
# Enterprise
# company
# •
# 78 followers
# Aledade Inc
# Enterprise
# company
# •
# 57 followers
# IBM Granite
# Enterprise
# company
# •
# 70 models
# •
# 843 followers
# Arcee AI
# Enterprise
# company
# •
# 131 models
# •
# 320 followers
# HiddenLayer
# Enterprise
# company
# •
# 53 followers
# Ekimetrics
# Enterprise
# company
# •
# 50 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 37 followers
# Widn AI
# Enterprise
# company
# •
# 29 followers
# BRIA AI
# Enterprise
# company
# •
# 29 models
# •
# 2.15k followers
# Shopify
# Enterprise
# company
# •
# 385 followers
# AI at Meta
# Enterprise
# company
# •
# 2.06k models
# •
# 4.24k followers
# Cerebras
# Enterprise
# company
# •
# 17 models
# •
# 437 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 8 models
# •
# 96 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 118 followers
# Mistral AI_
# Enterprise
# company
# •
# 21 models
# •
# 4.1k followers
# Xsolla
# Enterprise
# company
# •
# 54 followers
# Virtusa Corporation
# Enterprise
# company
# •
# 55 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 97 followers
# creditkarma
# Enterprise
# company
# •
# 37 followers
# Gretel.ai
# Enterprise
# company
# •
# 8 models
# •
# 88 followers
# Kakao Corp.
# Enterprise
# company
# •
# 45 followers
# Adyen
# Enterprise
# company
# •
# 38 followers
# Liquid AI
# Enterprise
# company
# •
# 96 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord

# %%
# Here you can personalize the tone, design, and sections... of your brochure
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short humorous, entertaining, jokey, and professional brochure about the company for prospective customers, investors, and recruits. Respond in markdown.\
Include details of company culture, customers, and careers/jobs if you have the information. Include at the end of the brochure all the relevant links with their correct path"

# %%
# Prepare a user prompt with company website details for brochure generation
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/brand'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'contact page', 'url': 'https://huggingface.co/chat'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nTrending on\nthis week\nModels\ndeepseek-ai/DeepSeek-R1\nUpdated\n1 day ago\n•\n69.6k\n•\n2.21k\nhexgrad/Kokoro-82M\nUpdated\n2 days ago\n•\n33.9k\n•\n2.32k\ndeepseek-ai/DeepSeek-R1-Distill-Qwen-32B\nUpdated\n1 day ago\n•\n75.9k\n•\n429\ndeepseek-ai/DeepSeek-R1-Zero\nUpdated\n1 day ago\n•\n4.48k\n•\n395\ndeepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B\nUpdated\n1 day ago\n•\n70.1k\n•\n328\nBrowse 400k+ models\nSpaces\nRunning\non\nZero\n1.47k\n❤️\nKokoro TTS\nNow in 5 languages!\nRunning\non\nZero\n312\n🌍\nHunyuan3D-2.0\nText-to-3D and Image-to-3D Generation\nRunning\non\nZero\n1.92k\n📈\nIC Light V2\nRunning\non\nZero\n3.28k\n🏢\nTRELLIS\nScalable and Versatile 3D Generation from images\nRunning\n207\n🧠\nDeepSeek-R1 WebGPU\nNext-generation reasoning model that runs locally in-browser\nBrowse 150k+ applications\nDatasets\nfka/awesome-chatgpt-prompts\nUpdated\n19 days ago\n•\n6.89k\n•\n7.06k\nHumanLLMs/Human-Like-DPO-Dataset\nUpdated\n12 days ago\n•\n1.62k\n•\n158\nbespokelabs/Bespoke-Stratos-17k\nUpdated\nabout 15 hours ago\n•\n1.9k\n•\n58\ncais/hle\nUpdated\n1 day ago\n•\n406\n•\n55\nyale-nlp/MMVU\nUpdated\n2 days ago\n•\n1.31k\n•\n47\nBrowse 100k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n378 models\n•\n1.94k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.06k models\n•\n4.24k followers\nAmazon Web Services\ncompany\n•\n20 models\n•\n2.58k followers\nGoogle\ncompany\n•\n913 models\n•\n6.8k followers\nIntel\ncompany\n•\n218 models\n•\n2.17k followers\nMicrosoft\ncompany\n•\n353 models\n•\n7.66k followers\nGrammarly\ncompany\n•\n10 models\n•\n115 followers\nWriter\nEnterprise\ncompany\n•\n18 models\n•\n200 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n137,968\nState-of-the-art ML for Pytorch, TensorFlow, and JAX.\nDiffusers\n27,265\nState-of-the-art diffusion models for image and audio generation in PyTorch.\nSafetensors\n3,019\nSimple, safe way to store and distribute neural networks weights safely and quickly.\nHub Python Library\n2,245\nClient library for the HF Hub: manage repositories from your Python runtime.\nTokenizers\n9,275\nFast tokenizers, optimized for both research and production.\nPEFT\n17,053\nParameter efficient finetuning methods for large models.\nTransformers.js\n12,672\nState-of-the-art Machine Learning for the web. Run Transformers directly in your browser, with no need for a server.\ntimm\n32,990\nState-of-the-art computer vision models, layers, optimizers, training/evaluation, and utilities. ...

# %%
# Adding the stream parameter, the results stream back from OpenAI
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}]}
# # Welcome to Hugging Face: Where AI Gets a Hug!
#
# ---
#
# ## Who Are We?
#
# At **Hugging Face**, we're not just another tech company; we're a vibrant community dedicated to shaping the future of Artificial Intelligence. Think of us as the cozy library of machine learning where everyone is invited to create, collaborate, and share. And yes, we're all about the hugs—just not the kind that makes you awkward at parties!
#
# ---
#
# ## What Do We Do?
#
# **Models, Datasets, and Spaces** - Oh my!
#
# - **400k+ Models:** From deep learning leviathans to the tiny models that might just blow your mind (in a good way).
# - **100k+ Datasets:** Because we believe there's a dataset out there for every bizarre niche you can think of. Seriously, you haven’t lived until you've analyzed the sentiments of cat memes!
# - **150k+ Applications:** Whether you're here to create, collaborate, or just see what all this fuss is about, we've got an application for you.
#
# ---
#
# ## Our Customers
#
# Join the ranks of **over 50,000 organizations**, including heavyweights like Google, Microsoft, and AWS. Even the folks at Grammarly prefer us for their ML needs (yes, those venerated grammarians trust us with their spelling)!
#
# ---
#
# ## The Hugging Face Culture
#
# Picture this: a collaborative haven where everyone’s ideas matter. We value innovation and creativity while maintaining a fun atmosphere—because who said serious business can't involve a few laughs (or a pun or two)? Our employees are as diverse and creative as our datasets, and we're always looking to expand the family!
#
# ---
#
# ## Come Work With Us!
#
# Are you ready to help build the future? We’re on the lookout for trailblazers in AI who aren't afraid to roll up their sleeves and get their hands dirty (virtually, of course). Check out our **careers page** for opportunities that will turn your workplace into a launching pad for your innovative dreams.
#
# ---
#
# ## Why Choose Hugging Face?
#
# Because saving the world through AI is better with friends (and hugs)! We’ll equip you with the tools to accelerate your models and projects, and throw in some community vibes for free.
#
# ---
#
# ## Dive In!
#
# - [Explore Models](https://huggingface.co/models)
# - [Datasets Galore](https://huggingface.co/datasets)
# - [Launch Your Space](https://huggingface.co/spaces)
# - [Join the Community](https://huggingface.co/community)
# - [Careers at Hugging Face](https://huggingface.co/jobs)
#
#
# ---
#
# So, what are you waiting for? Embrace the AI revolution—let’s build the future together, one hug at a time!
#
# ---
#
# **Hugging Face - Not just a name, a mission!**

# %%
stream_brochure("Villefranche-sur-Mer", "https://villefranche-sur-mer.fr")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://villefranche-sur-mer.fr/mairie/'}, {'type': 'services page', 'url': 'https://villefranche-sur-mer.fr/services-municipaux/'}, {'type': 'council page', 'url': 'https://villefranche-sur-mer.fr/conseil-municipal/'}, {'type': 'local news page', 'url': 'https://villefranche-sur-mer.fr/villefranche-news/'}, {'type': 'events page', 'url': 'https://villefranche-sur-mer.fr/events/'}, {'type': 'contact page', 'url': 'https://villefranche-sur-mer.fr/nous-contacter/'}, {'type': 'careers page', 'url': 'https://villefranche-sur-mer.fr/la-ville-recherche-une-controleurse-de-travaux-et-des-infractions-en-urbanisme-h-f/'}]}
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# OSError: [Errno 12] Cannot allocate memory
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/urllib3/connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/urllib3/connection.py:704, in HTTPSConnection.connect(self)
#     703 sock: socket.socket | ssl.SSLSocket
# --> 704 self.sock = sock = self._new_conn()
#     705 server_hostname: str = self.host
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/urllib3/connection.py:213, in HTTPConnection._new_conn(self)
#     212 except OSError as e:
# --> 213     raise NewConnectionError(
#     214         self, f"Failed to establish a new connection: {e}"
#     215     ) from e
#     217 sys.audit("http.client.connect", self, self.host, self.port)
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x113009c90>: Failed to establish a new connection: [Errno 12] Cannot allocate memory
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='villefranche-sur-mer.fr', port=443): Max retries exceeded with url: /villefranche-news/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x113009c90>: Failed to establish a new connection: [Errno 12] Cannot allocate memory'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 stream_brochure("Villefranche-sur-Mer", "https://villefranche-sur-mer.fr")
#
# Cell In[63], line 7, in stream_brochure(company_name, url)
#       2 def stream_brochure(company_name, url):
#       3     stream = openai.chat.completions.create(
#       4         model=MODEL,
#       5         messages=[
#       6             {"role": "system", "content": system_prompt},
# ----> 7             {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
#       8           ],
#       9         stream=True
#      10     )
#      12     response = ""
#      13     display_handle = display(Markdown(""), display_id=True)
#
# Cell In[61], line 5, in get_brochure_user_prompt(company_name, url)
#       3 user_prompt = f"You are looking at a company called: {company_name}\n"
#       4 user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
# ----> 5 user_prompt += get_all_details(url)
#       6 user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
#       7 return user_prompt
#
# Cell In[58], line 9, in get_all_details(url)
#       7 for link in links["links"]:
#       8     result += f"\n\n{link['type']}\n"
# ----> 9     result += Website(link["url"]).get_contents()
#      10 return result
#
# Cell In[49], line 14, in Website.__init__(self, url)
#      12 def __init__(self, url):
#      13     self.url = url
# ---> 14     response = requests.get(url, headers=headers)
#      15     self.body = response.content
#      16     soup = BeautifulSoup(self.body, 'html.parser')
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='villefranche-sur-mer.fr', port=443): Max retries exceeded with url: /villefranche-news/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x113009c90>: Failed to establish a new connection: [Errno 12] Cannot allocate memory'))
